# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

# %%
# Load the data
data = pd.read_table('developments_in_high_throughput_sequencing.tsv', sep ='\t')

# %%
# Get a list of instruments
instruments = data.Label.unique()

# %%
instruments
# Out:
# array(['ABI Sanger 3730xl', '454 GS FLX', '454 GS Junior', 'Illumina GA',
#        'Illumina HiSeq 2000/2500', 'Illumina HiSeq 2500 RR',
#        'Illumina HiSeq 4000', 'Illumina HiSeq X', 'Illumina NextSeq 500',
#        'Illumina NextSeq 550', 'Illumina iSeq', 'Illumina NextSeq 1000',
#        'Illumina MiSeq', 'Illumina MiniSeq', 'Illumina NovaSeq 6000',
#        'SOLiD', 'IonTorrent PGM ', 'IonTorrent Proton',
#        'Ion GeneStudio S5', 'Ion Torrent Genexus Integrated Sequencer',
#        'PacBio RS', 'Oxford Nanopore MinION Mk1'], dtype=object)

# %%
# Set up the plot
plt.figure(figsize=(10,10))
ax = plt.subplot(1,1,1)
plt.xlabel('Read length (log scale)', fontsize=14)
plt.ylabel('Gigabses per run (log scale)', fontsize=14)

# Plot the data
for instrument in instruments:
    reads = data[data.Label == instrument]['Read length (mode or average)']
    bases = data[data.Label == instrument]['Bases per run (gigabases)']
    plt.plot(reads, bases, 'o-', label = instrument)

# Set scales, labels
ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(10,15000)
plt.ylim(0.00001,15000)
ax.set_xticklabels(['1','10','100','1000','10000','100000','10000000'], fontsize=14) # Need to expand list to show the one I want
ax.set_yticklabels(['0.000001','0.00001','0.0001','0.001','0.01','0.1','1','10','100','1000','10000'], fontsize=14)

# Adjust border, remove right and top
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Prepare legend box OUTSIDE of plot
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height])
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# finish
plt.savefig('developments_in_high_throughput_sequencing_bare.png', orientation='landscape')
plt.show()
# Out:
# C:\Users\kevin.lam2\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\kevin.lam2\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
len(instruments)
# Out:
# 19

# %%
markers=['.',"o","v","^","<",">","8","s","p","*"]
len(markers)
# Out:
# 10

# %%
instruments2=['Illumina NextSeq 550', 'Illumina iSeq', 'Illumina NextSeq 1000',
       'Illumina MiSeq', 'Illumina MiniSeq', 'Illumina NovaSeq 6000',
       'Ion GeneStudio S5', 'Ion Torrent Genexus Integrated Sequencer']
len(instruments2)
# Out:
# array(['3730xl', 'GS20', 'GS FLX', 'GS FLX Titanium', 'GS FLX+',
#        'GS Junior', 'GS Junior+', 'GA', 'GA II', 'GAIIx', 'HiSeq 2000',
#        'HiSeq 2000/2500', 'HiSeq 2500 RR', 'HiSeq 4000', 'HiSeq X',
#        'NextSeq 500', 'NextSeq 550', 'iSeq', 'NextSeq 1000', 'MiSeq',
#        'MiniSeq', 'NovaSeq', '1', '2', '3', '4', '5500xl', '5500xl W',
#        'PGM 314 chip', 'PGM 316 chip', 'PGM 318 chip', 'PGM 318 chip V2',
#        'Proton PI', 'Ion 510 Chip', 'Ion 520 Chip', 'Ion 530 chip',
#        'Ion 540 chip', 'Ion 550 chip', 'GX5 chip Single Lane',
#        'GX5 chip 2 Lanes', 'GX5 chip 3 Lanes', 'GX5 chip Full Chip',
#        'RS C1', 'RS C2', 'RS C2 XL', 'RS II C2 XL', 'RS II P5 C3',
#        'RS II P6 C4', 'MinION Mk1', 'MinION Mk1 fast'], dtype=object)

# %%
# Set up the plot
plt.figure(figsize=(10,10))
ax = plt.subplot(1,1,1)
plt.xlabel('Read length (log scale)', fontsize=14)
plt.ylabel('Gigabses per run (log scale)', fontsize=14)
counter=0
# Plot the data
for instrument in instruments2:
    reads = data[data.Label == instrument]['Read length (mode or average)']
    bases = data[data.Label == instrument]['Bases per run (gigabases)']
    plt.scatter(reads, bases, marker=markers[counter], label = instrument)
    counter+=1

# Set scales, labels
ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(50,15000)
plt.ylim(0.001,15000)
ax.set_xticklabels(['100','1000','10000','100000','10000000'], fontsize=14) # Need to expand list to show the one I want
ax.set_yticklabels(['0.001','0.01','0.1','1','10','100','1000'], fontsize=14)

# Adjust border, remove right and top
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Prepare legend box OUTSIDE of plot
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height])
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# finish
plt.savefig('developments_in_high_throughput_sequencing_bare_current.png', orientation='landscape')
plt.show()
# Out:
# C:\Users\kevin.lam2\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\kevin.lam2\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# Get a list of chips
chips = data.Instrument.unique()
chips

rng = np.random.RandomState(0)
colors = rng.rand(len(instruments))
print(colors)
 
print(chips)
# Set up the plot
plt.figure(figsize=(10,10))
ax = plt.subplot(1,1,1)
plt.xlabel('Read length (log scale)', fontsize=14)
plt.ylabel('Gigabses per run (log scale)', fontsize=14)
counter=0
plt.scatter(data['Read length (mode or average)'],data['Bases per run (gigabases)'],label=data['Label'])


# Set scales, labels
ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(50,15000)
plt.ylim(0.001,15000)
ax.set_xticklabels(['100','1000','10000','100000','10000000'], fontsize=14) # Need to expand list to show the one I want
ax.set_yticklabels(['0.001','0.01','0.1','1','10','100','1000'], fontsize=14)

# Adjust border, remove right and top
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Prepare legend box OUTSIDE of plot
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height])
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#Now this is actually the code that you need, an easy fix your colors just cut and paste not you need ax.
colormap = plt.cm.gist_ncar #nipy_spectral, Set1,Paired  
colorst = [colormap(i) for i in np.linspace(0, 0.9,len(ax.collections))]       
for t,j1 in enumerate(ax.collections):
    j1.set_color(colorst[t])


# finish
plt.savefig('developments_in_high_throughput_sequencing_bare_current-chips.png', orientation='landscape')
plt.show()
# Out:
# [0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411
#  0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492
#  0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985
#  0.77815675 0.87001215 0.97861834 0.79915856]
# ['3730xl' 'GS20' 'GS FLX' 'GS FLX Titanium' 'GS FLX+' 'GS Junior'
#  'GS Junior+' 'GA' 'GA II' 'GAIIx' 'HiSeq 2000' 'HiSeq 2000/2500'
#  'HiSeq 2500 RR' 'HiSeq 4000' 'HiSeq X' 'NextSeq 500' 'NextSeq 550' 'iSeq'
#  'NextSeq 1000' 'MiSeq' 'MiniSeq' 'NovaSeq' '1' '2' '3' '4' '5500xl'
#  '5500xl W' 'PGM 314 chip' 'PGM 316 chip' 'PGM 318 chip' 'PGM 318 chip V2'
#  'Proton PI' 'Ion 510 Chip' 'Ion 520 Chip' 'Ion 530 chip' 'Ion 540 chip'
#  'Ion 550 chip' 'GX5 chip Single Lane' 'GX5 chip 2 Lanes'
#  'GX5 chip 3 Lanes' 'GX5 chip Full Chip' 'RS C1' 'RS C2' 'RS C2 XL'
#  'RS II C2 XL' 'RS II P5 C3' 'RS II P6 C4' 'MinION Mk1' 'MinION Mk1 fast']
# ...

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
print(colors)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,cmap='viridis')
plt.colorbar();  # show color scale
# Out:
# [0.96193638 0.29214753 0.24082878 0.10029394 0.01642963 0.92952932
#  0.66991655 0.78515291 0.28173011 0.58641017 0.06395527 0.4856276
#  0.97749514 0.87650525 0.33815895 0.96157015 0.23170163 0.94931882
#  0.9413777  0.79920259 0.63044794 0.87428797 0.29302028 0.84894356
#  0.61787669 0.01323686 0.34723352 0.14814086 0.98182939 0.47837031
#  0.49739137 0.63947252 0.36858461 0.13690027 0.82211773 0.18984791
#  0.51131898 0.22431703 0.09784448 0.86219152 0.97291949 0.96083466
#  0.9065555  0.77404733 0.33314515 0.08110139 0.40724117 0.23223414
#  0.13248763 0.05342718 0.72559436 0.01142746 0.77058075 0.14694665
#  0.07952208 0.08960303 0.67204781 0.24536721 0.42053947 0.55736879
#  0.86055117 0.72704426 0.27032791 0.1314828  0.05537432 0.30159863
#  0.26211815 0.45614057 0.68328134 0.69562545 0.28351885 0.37992696
#  0.18115096 0.78854551 0.05684808 0.69699724 0.7786954  0.77740756
#  0.25942256 0.37381314 0.58759964 0.2728219  0.3708528  0.19705428
# ...

# %%
plt.figure(figsize=(10,10))
ax = plt.subplot(1,1,1)
plt.xlabel('Read length (log scale)', fontsize=14)
plt.ylabel('Gigabses per run (log scale)', fontsize=14)
counter=0
colors = rng.rand(10)
# Plot the data
for instrument in instruments2:
    reads = data[data.Label == instrument]['Read length (mode or average)']
    bases = data[data.Label == instrument]['Bases per run (gigabases)']
    plt.scatter(reads, bases,marker=markers[counter], label = instrument)
    counter+=1

# Set scales, labels
ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(50,1000)
plt.ylim(0.001,15000)
ax.set_xticklabels(['100','1000','10000','100000'], fontsize=14) # Need to expand list to show the one I want
#ax.set_yticklabels(['0.001','0.01','0.1','1','10','100','1000'], fontsize=14)

# Adjust border, remove right and top
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Prepare legend box OUTSIDE of plot
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height])
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# finish
plt.savefig('developments_in_high_throughput_sequencing_bare_current.png', orientation='landscape')
plt.show()
# Out:
# C:\Users\kevin.lam2\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# %matplotlib widget

plt.figure(figsize=(10,10))
ax = plt.subplot(1,1,1)
plt.xlabel('Read length (log scale)', fontsize=14)
plt.ylabel('Gigabses per run (log scale)', fontsize=14)
counter=0
colors = rng.rand(10)
# Plot the data
for instrument in instruments2:
    reads = data[data.Label == instrument]['Read length (mode or average)']
    bases = data[data.Label == instrument]['Bases per run (gigabases)']
    plt.scatter(reads, bases,marker=markers[counter], label = instrument)
    counter+=1

# Set scales, labels
ax.set_xscale('log')
ax.set_yscale('log')
plt.xlim(50,1000)
plt.ylim(0.001,15000)
ax.set_xticklabels(['100','1000','10000','100000'], fontsize=14) # Need to expand list to show the one I want
#ax.set_yticklabels(['0.001','0.01','0.1','1','10','100','1000'], fontsize=14)

# Adjust border, remove right and top
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Prepare legend box OUTSIDE of plot
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height])
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# finish
plt.show()
# Out:
# C:\Users\kevin.lam2\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
